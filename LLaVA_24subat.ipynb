# %% [markdown]
# <a href="https://colab.research.google.com/github/Aosm26/Aosm26/blob/main/LLaVA_24subat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone https://github.com/haotian-liu/LLaVA.git

# %cd /content/LLaVA

# !pip install --upgrade pip
# !pip install -e .
# Out:
# /content
# Cloning into 'LLaVA'...
# remote: Enumerating objects: 2297, done.
# remote: Total 2297 (delta 0), reused 0 (delta 0), pack-reused 2297 (from 1)
# Receiving objects: 100% (2297/2297), 13.71 MiB | 27.58 MiB/s, done.
# Resolving deltas: 100% (1404/1404), done.
# /content/LLaVA
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 19.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/base_command.py", line 179, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/req_command.py", line 67, in wrapper
#     return func(self, options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/commands/install.py", line 455, in run
#     installed = install_given_reqs(
#                 ^^^^^^^^^^^^^^^^^^^
# ...

# %%
# !pip install -e ".[train]"
# !pip install flash-attn --no-build-isolation
# Out:
# Obtaining file:///content/LLaVA
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 16.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
# WARNING: typer 0.15.1 does not provide the extra 'all'
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.9/422.9 kB 34.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 4.1 MB/s eta 0:00:00
# ...
#   Building editable for llava (pyproject.toml) ... done
#   Created wheel for llava: filename=llava-1.2.2.post1-0.editable-py3-none-any.whl size=17852 sha256=bfdf8bbfdbe490be6e6ebb9918eb8df64bbb70ea106a6f30ba2c31c5a88c1a0c
# ...
